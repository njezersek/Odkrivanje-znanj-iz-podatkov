# %% [markdown]
# # Tekmovanje

# %%
import pandas as pd
import numpy as np
from datetime import date, datetime, timedelta
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
def createLabel(data):
	return data['Route'].astype(str) + "-|-" + data['Route Direction'] + "-|-" + data['Route description'] #+ "-|-" + data['First station'] + "-|-" + data['Last station']

# %%
train = pd.read_csv('train.csv', sep='\t')
test = pd.read_csv('test.csv', sep='\t')

train['label'] = createLabel(train)
test['label'] = createLabel(test)

weather_data = pd.read_csv('weather_data.csv', sep='\t', index_col=0)
prazniki = pd.read_csv('prazniki_prosti.txt', sep='\t', index_col=0, header=None)
pocitnice = pd.read_csv('pocitnice.txt', sep='\t', index_col=0, header=None)

# %%
len(set(train['Driver ID'].values))
# Out:
# 430

# %% [markdown]
# Podatkom dodajmo ključe, ki enolično identificirajo linijo.
#
# Na koncu prikažemo število učnih podatkov za vsako linijo iz testnih podatkov.

# %%
train_routes = {s for s in train['label']}
test_routes = {s for s in test['label']}

s = sorted([(l, len(train['label'][train['label'] == l]), len(test['label'][test['label'] == l])) for l in test_routes], key=lambda x: x[1])
print(len(s))
s
# Out:
# 121
# [('1-|-MESTNI LOG - VIŽMARJE-|-  VIŽMARJE; sejem', 0, 827),
#  ('1-|-VIŽMARJE - MESTNI LOG-|-  MESTNI LOG; sejem', 0, 865),
#  ('30-|-MEDVODE - VODICE-|-  VODICE', 38, 100),
#  ('30-|-VODICE - MEDVODE-|-  MEDVODE', 41, 85),
#  ('14-|-B BOKALCE - GARAŽA-|-  GARAŽA', 91, 5),
#  ('27-|-NS RUDNIK - GARAŽA-|-  GARAŽA', 104, 2),
#  ('2-|-ZELENA JAMA - GARAŽA-|-  GARAŽA', 105, 6),
#  ('1-|-N BAVARSKI DVOR - VIŽMARJE-|-N VIŽMARJE', 107, 7),
#  ('27-|-LETALIŠKA - GARAŽA-|-  GARAŽA', 130, 3),
#  ('3-|-N ŠKOFLJICA - BAVARSKI DVOR-|-N BAVARSKI DVOR', 135, 10),
#  ('8-|-GAMELJNE - BAVARSKI DVOR-|-  BAVARSKI DVOR', 148, 10),
#  ('27-|-K KOLOSEJ - BLEIWEISOVA-|-K BAVARSKI DVOR', 170, 9),
#  ('15-|-MEDVODE - STANEŽIČE-|-  STANEŽIČE', 185, 140),
#  ('3-|-L TOVARNA LEK - BAVARSKI DVOR-|-L BAVARSKI DVOR', 192, 6),
#  ('19-|- I TOMAČEVO - GARAŽA-|-  GARAŽA', 198, 5),
#  ('27-|-K BLEIWEISOVA - KOLOSEJ-|-K KOLOSEJ', 199, 22),
#  ('15-|-STANEŽIČE - MEDVODE-|-  MEDVODE', 201, 138),
#  ('1-|-N VIŽMARJE - BAVARSKI DVOR-|-  BAVARSKI DVOR', 203, 12),
#  ('3-|-LITOSTROJ - RUDNIK-|-N RUDNIK', 204, 13),
#  ('5-|-PODUTIK - GARAŽA-|-  GARAŽA', 207, 9),
#  ('40-|-40114 IG-I.Loka.-Strahomer-IŠKA VAS-|-  IŠKA VAS', 210, 34),
#  ('42-|-42108 IG-VISOKO-ZAPOTOK-|-  ZAPOTOK', 227, 18),
#  ('29-|-KODELJEVO - O.Š. SOSTRO - TUJI GRM-|-  TUJI GRM', 227, 15),
#  ('2-|-NOVE JARŠE - GARAŽA-|-  GARAŽA', 228, 10),
#  ('28-|-MALI LIPOGLAV - KODELJEVO-|-  KODELJEVO', 229, 3),
#  ('20-|-NOVE STOŽICE - GARAŽA-|-  GARAŽA', 244, 6),
#  ('11-|-BEŽIGRAD - ZALOG-|-N ZALOG', 251, 19),
#  ('28-|-KODELJEVO - MALI LIPOGLAV-|-  MALI LIPOGLAV', 268, 13),
#  ('19-|-I TOMAČEVO - IŠKA VAS-|-I IŠKA VAS', 287, 55),
#  ('25-|-ZADOBROVA - GARAŽA-|-  GARAŽA', 289, 14),
#  ('40-|-40111 IG-I.Loka-Tomiš.A.-Iška vas-IG -|-  IŠKA VAS', 290, 13),
#  ('3-|-N BAVARSKI DVOR - ŠKOFLJICA-|-N ŠKOFLJICA', 311, 20),
#  ('13-|-CENTER STOŽICE - GARAŽA-|-  GARAŽA', 311, 5),
#  ('6-|-B NOTRANJE GORICE - GARAŽA-|-B GARAŽA', 343, 14),
#  ('19-|-I IŠKA VAS - TOMAČEVO-|-I TOMAČEVO', 343, 57),
#  ('1-|-N GAMELJNE - BAVARSKI DVOR-|-N BAVARSKI DVOR', 419, 17),
#  ('1-|-N MESTNI LOG - BAVARSKI DVOR - GAMELJNE-|-N GAMELJNE', 438, 12),
#  ('1-|-MESTNI LOG - GARAŽA-|-  GARAŽA', 455, 2),
#  ('8-|-BRNČIČEVA - GARAŽA-|-  GARAŽA', 463, 21),
#  ('3-|-B ŠKOFLJICA - GARAŽA-|-  GARAŽA', 471, 18),
#  ('20-|-FUŽINE - GARAŽA-|-  GARAŽA', 497, 16),
#  ('1-|-N BROD - GARAŽA-|-  GARAŽA', 513, 16),
#  ('40-|-40110 IG-I.Loka-Strahomer-Iška Vas-IG-|-  IŠKA VAS', 540, 3),
#  ('8-|-GAMELJNE - GARAŽA-|-  GARAŽA', 592, 28),
#  ('1-|-B MESTNI LOG - GAMELJNE-|-B GAMELJNE; sejem', 597, 55),
#  ('5-|-ŠTEPANJSKO NAS. - GARAŽA-|-  GARAŽA', 603, 23),
#  ('13-|-SOSTRO - GARAŽA-|-  GARAŽA', 635, 50),
#  ('42-|-42107 IG-ZAPOTOK-|-  ZAPOTOK', 659, 39),
#  ('1-|-N BROD - BAVARSKI DVOR-|-N BAVARSKI DVOR', 673, 30),
#  ('6-|-B NOTRANJE GORICE - DM - ČRNUČE-|-B ČRNUČE', 674, 41),
#  ('11-|-ZALOG - GARAŽA-|-  GARAŽA', 676, 24),
#  ('1-|-B GAMELJNE - MESTNI LOG-|-B MESTNI LOG; sejem', 693, 20),
#  ('7-|-NOVE JARŠE - GARAŽA-|-  GARAŽA', 730, 36),
#  ('14-|-VRHOVCI - GARAŽA-|-  GARAŽA', 730, 31),
#  ('9-|-TRNOVO - GARAŽA-|-  GARAŽA', 828, 32),
#  ('6-|-DOLGI MOST - GARAŽA-|-  GARAŽA', 847, 61),
#  ('1-|-B MESTNI LOG - GAMELJNE-|-B GAMELJNE', 1032, 50),
#  ('19-|-B TOMAČEVO - JEZERO-|-B JEZERO', 1066, 31),
#  ('1-|-N BAVARSKI DVOR - BROD-|-N BROD', 1113, 53),
#  ('1-|-B GAMELJNE - MESTNI LOG -|-B MESTNI LOG', 1156, 17),
#  ('25-|-MEDVODE - GARAŽA-|-  GARAŽA', 1177, 85),
#  ('6-|-ČRNUČE - GARAŽA-|-  GARAŽA', 1407, 59),
#  ('3-|-N RUDNIK - BAVARSKI DVOR-|-N BAVARSKI DVOR', 1433, 94),
#  ('20-|-Z ZALOG - NOVE STOŽICE-|-Z NOVE STOŽICE', 1434, 102),
#  ('14-|-SAVLJE - GARAŽA-|-  GARAŽA', 1471, 59),
#  ('3-|-RUDNIK - GARAŽA-|-  GARAŽA', 1512, 84),
#  ('9-|-ŠTEPANJSKO NAS. - GARAŽA-|-  GARAŽA', 1573, 61),
#  ('3-|-G GROSUPLJE - BEŽIGRAD -|-G BEŽIGRAD', 1642, 274),
#  ('20-|-Z NOVE STOŽICE - ZALOG-|-Z ZALOG', 1649, 110),
#  ('3-|-G BEŽIGRAD - GROSUPLJE-|-G GROSUPLJE', 1660, 266),
#  ('5-|-N PODUTIK - ŠTEPANJSKO NAS.-|-N ŠTEPANJSKO NAS.', 1986, 106),
#  ('24-|-KODELJEVO - BIZOVIK-|-  BIZOVIK', 2163, 133),
#  ('5-|-N ŠTEPANJSKO NAS. - PODUTIK-|-N PODUTIK', 2201, 96),
#  ('3-|-N BAVARSKI DVOR - RUDNIK-|-N RUDNIK', 2203, 112),
#  ('12-|-BEŽIGRAD - VEVČE-|-  VEVČE', 2448, 142),
#  ('21-|-BERIČEVO - JEŽICA-|-  JEŽICA', 2669, 97),
#  ('12-|-VEVČE - BEŽIGRAD-|-  BEŽIGRAD', 2975, 86),
#  ('27-|-NS RUDNIK - BTC - LETALIŠKA-|-  LETALIŠKA', 2979, 128),
#  ('22-|-KAMNA GORICA - FUŽINE-|-  FUŽINE', 3076, 131),
#  ('11-|-BEŽIGRAD - ZALOG-|-B ZALOG', 3082, 167),
#  ('22-|-FUŽINE - KAMNA GORICA-|-  KAMNA GORICA', 3240, 156),
#  ('27-|-LETALIŠKA - BTC - NS RUDNIK-|-  N.S. RUDNIK', 3240, 170),
#  ('24-|-BIZOVIK - KODELJEVO-|-  KODELJEVO', 3353, 147),
#  ('21-|-JEŽICA - BERIČEVO-|-  BERIČEVO', 3438, 168),
#  ('25-|-ZADOBROVA - MEDVODE-|-  MEDVODE', 3669, 339),
#  ('11-|-ZALOG - BEŽIGRAD-|-B BEŽIGRAD', 3689, 171),
#  ('7-|-L LETALIŠKA - PRŽAN-|-  PRŽAN', 4710, 228),
#  ('6-|-B NOTRANJE GORICE - ČRNUČE-|-B ČRNUČE', 4900, 259),
#  ('2-|-NOVE JARŠE - ZELENA JAMA-|-  ZELENA JAMA', 4964, 218),
#  ('3-|-B LITOSTROJ - ŠKOFLJICA-|-B ŠKOFLJICA', 5112, 250),
#  ('7-|-L PRŽAN - LETALIŠKA-|-L LETALIŠKA', 5140, 251),
#  ('3-|-B ŠKOFLJICA - LITOSTROJ-|-B LITOSTROJ', 5197, 230),
#  ('18-|-TOVARNA LEK - KINO ŠIŠKA-|-  KINO ŠIŠKA', 5368, 194),
#  ('18-|-KINO ŠIŠKA - TOVARNA LEK-|-  TOVARNA LEK', 5407, 148),
#  ('3-|-RUDNIK - LITOSTROJ-|-  LITOSTROJ', 5521, 246),
#  ('2-|-ZELENA JAMA - NOVE JARŠE-|-  NOVE JARŠE', 5907, 222),
#  ('6-|-B ČRNUČE - NOTRANJE GORICE-|-B NOTRANJE GORICE', 6082, 319),
#  ('25-|-MEDVODE - ZADOBROVA-|-  ZADOBROVA', 6713, 359),
#  ('13-|-SOSTRO - CENTER STOŽICE-|-  CENTER STOŽICE', 7657, 368),
#  ('14-|-B BOKALCE - SAVLJE-|-B SAVLJE', 7739, 425),
#  ('13-|-CENTER STOŽICE - SOSTRO-|-  SOSTRO', 7812, 453),
#  ('14-|-VRHOVCI - SAVLJE-|-  SAVLJE', 8707, 468),
#  ('3-|-LITOSTROJ - RUDNIK-|-  RUDNIK', 8845, 509),
#  ('14-|-B SAVLJE - BOKALCE-|-B BOKALCE', 9059, 391),
#  ('14-|-SAVLJE - VRHOVCI-|-  VRHOVCI', 9484, 434),
#  ('11-|-ZALOG - JEŽICA-|-  JEŽICA', 10223, 542),
#  ('7-|-NOVE JARŠE - PRŽAN-|-  PRŽAN', 10692, 586),
#  ('8-|-GAMELJNE - BRNČIČEVA-|-  BRNČIČEVA', 11584, 598),
#  ('11-|-JEŽICA - ZALOG-|-  ZALOG', 11749, 496),
#  ('7-|-PRŽAN - NOVE JARŠE-|-  NOVE JARŠE', 12580, 514),
#  ('8-|-BRNČIČEVA - GAMELJNE-|-  GAMELJNE', 12819, 605),
#  ('5-|-PODUTIK - ŠTEPANJSKO NAS.-|-  ŠTEPANJSKO NAS.', 14357, 763),
#  ('5-|-ŠTEPANJSKO NAS. - PODUTIK-|-  PODUTIK', 14525, 763),
#  ('20-|-NOVE STOŽICE - FUŽINE-|-  FUŽINE', 15672, 789),
#  ('9-|-ŠTEPANJSKO NAS. - TRNOVO-|-  TRNOVO', 15995, 825),
#  ('20-|-FUŽINE - NOVE STOŽICE-|-  NOVE STOŽICE', 16199, 830),
#  ('9-|-TRNOVO - ŠTEPANJSKO NAS.-|-  ŠTEPANJSKO NAS.', 16596, 860),
#  ('6-|-DOLGI MOST - ČRNUČE-|-  ČRNUČE', 17094, 944),
#  ('1-|-VIŽMARJE - MESTNI LOG-|-  MESTNI LOG', 19105, 25),
#  ('1-|-MESTNI LOG - VIŽMARJE-|-  VIŽMARJE', 19919, 127),
#  ('6-|-ČRNUČE - DOLGI MOST-|-  DOLGI MOST', 20892, 965)]

# %% [markdown]
# # Prepare the data

# %%
def convert(data):
	d = pd.DataFrame()
	d['departure'] = pd.to_datetime(data['Departure time'])
	d['weekday'] = d['departure'].dt.weekday
	d['month'] = d['departure'].dt.month
	d['hour'] = d['departure'].dt.hour
	d['minute_of_day'] = d['departure'].dt.hour*60 + d['departure'].dt.minute
	d['second_of_day'] = d['departure'].dt.hour*3600 + d['departure'].dt.minute*60 + d['departure'].dt.second
	d['day_of_year'] = d['departure'].dt.dayofyear
	d['driver'] = data['Driver ID']
	d['driver_l'] = np.where(d['driver'] < 254, d['driver'], 254)
	d['driver_h'] = np.where(d['driver'] >= 255, d['driver']-255, 254)
	d['weather_key'] = ((d['departure'].copy().round('30min') - pd.to_datetime(date(1800,1,1))).dt.total_seconds()//60).astype(int)
	d['holiday'] = d['departure'].dt.strftime('%Y-%m-%d').isin(prazniki.index).astype(int)
	d['school_holiday'] = d['departure'].dt.strftime('%Y-%m-%d').isin(pocitnice.index).astype(int)
	d['label'] = data['First station'] + "---" + data['Last station']

	# seconds on the circle
	sec = (d["second_of_day"] / (24*60*60)) * 2 * np.pi
	d["sec_circ_x"] = np.cos(sec)
	d["sec_circ_y"] = np.sin(sec)

	# month on the circle
	month = (d["month"] / 12) * 2 * np.pi
	d["month_circ_x"] = np.cos(month)
	d["month_circ_y"] = np.sin(month)

	# day of year on the circle
	day = (d["day_of_year"] / 365) * 2 * np.pi
	d["day_circ_x"] = np.cos(day)
	d["day_circ_y"] = np.sin(day)

	# merge weather data
	d = pd.merge(d, weather_data, left_on='weather_key', right_index=True, how="left")
	d['freezing'] = (d['t2m'] < 0).astype(int)
	return d

# %%
def get_X_train_test(train, test):
	d = convert(train.append(test))
	t = d[["driver", "weekday", "month", "freezing", "school_holiday", "holiday", "sec_circ_x", "sec_circ_y", "day_circ_x", "day_circ_y", "padavine"]].values
	# t = d[["weekday", "month", "freezing", "school_holiday", "holiday", "second_of_day", "day_of_year", "t2m", "padavine", "veter_hitrost"]].values

	return t[:len(train)], t[len(train):], d[:len(train)]

def get_y_train(data):
	d = pd.DataFrame()
	d['departure'] = pd.to_datetime(data['Departure time'])	
	d['arrival'] = pd.to_datetime(data['Arrival time'])
	d['duration'] = (d['arrival'] - d['departure']).dt.total_seconds()

	return d['duration'].to_numpy()


def get_result(data, prediction):
	result = (pd.to_datetime(data['Departure time']) + pd.to_timedelta(prediction, unit='s')).round('1ms')
	return result

# %% [markdown]
# ## Average ✔

# %%
prediction = pd.DataFrame()
prediction['label'] = test['label']
prediction['start'] = test['Departure time']
prediction['duration'] = 0

for l in test_routes:
	X_train, X_test, t = get_X_train_test(train[train['label'] == l], test[test['label'] == l])
	y_train = get_y_train(train[train['label'] == l])
	
	y_pred = 0
	if(len(X_train) > 0):
		y_pred = np.mean(y_train)
	else:
		# y_pred = np.mean(get_y_train(train))
		s = 0
		n = 0
		for l2 in train_routes:
			if(l2 != l):
				s += np.mean(get_y_train(train[train['label'] == l2]))
				n += 1
		y_pred = s / n

	prediction.loc[prediction['label'] == l, 'duration'] = get_result(test[test['label'] == l], y_pred)

# %% [markdown]
# # Create models

# %%
X_train_all, X_test_all, t = get_X_train_test(train, test)
y_train_all = get_y_train(train)

# %%
def make_prediction(train, test):
	prediction = pd.DataFrame()
	prediction['label'] = test['label']
	prediction['start'] = test['Departure time']
	prediction['duration'] = 0

	routes = {s for s in test['label']} 

	for l in routes:
		# X_train, X_test, t = get_X_train_test(train[train['label'] == l], test[test['label'] == l])
		# y_train = get_y_train(train[train['label'] == l])
		X_train = X_train_all[train['label'] == l]
		X_test = X_test_all[test['label'] == l]
		y_train = y_train_all[train['label'] == l]
		
		y_pred = np.ones(len(X_test)) * 34 * 60
		if(len(X_train) > 0): # 
			reg = GradientBoostingRegressor(max_depth=13).fit(X_train, y_train)
			y_pred = reg.predict(X_test)
		else:
			y_pred = np.mean(get_y_train(train)) * np.ones(len(X_test))

		prediction.loc[prediction['label'] == l, 'arrival_prediction'] = get_result(test[test['label'] == l], y_pred)

	prediction['arrival_prediction_round'] = pd.to_datetime(prediction['arrival_prediction']).round('1ms')

	return prediction

# %%
for i in range(1, 12):
	t_test = train[pd.to_datetime(train['Departure time']).dt.month == i]
	t_train = train[pd.to_datetime(train['Departure time']).dt.month != i]

	prediction = make_prediction(t_test, t_test)
	error = (pd.to_datetime(t_test['Arrival time']) - pd.to_datetime(prediction['arrival_prediction_round'])).dt.total_seconds().values

	print(i, np.mean(np.abs(error)))

# %% [markdown]
# ```
# 1 101.68681694581282
# 2 111.40611644182377
# 3 114.87555887309112
# 4 116.97508007887225
# 5 128.51011340919575
# 6 108.35978541671118
# 7 91.69127673127448
# 8 92.97712371649138
# 9 115.06750550144667
# 10 127.08306864785148
# 11 116.07500394192104
# ```

# %%
prediction = make_prediction(train, test)

prediction[['arrival_prediction_round']].to_csv('result_t3_8.txt', index=False, header=False)

# %%
prediction = pd.DataFrame()
prediction['label'] = test['label']
prediction['start'] = test['Departure time']
prediction['duration'] = 0

MAEs = []

for l in test_routes:
	X_train, X_test, t = get_X_train_test(train[train['label'] == l], test[test['label'] == l])
	y_train = get_y_train(train[train['label'] == l])
	
	y_pred = np.ones(len(X_test)) * 34 * 60
	if(len(X_train) > 0):
		N = len(X_train) // 10
		X_t_train = X_train[:-N]
		X_t_test = X_train[-N:]
		y_t_train = y_train[:-N]
		y_t_test = y_train[-N:]

		reg_t = Ridge(alpha=3).fit(X_t_train, y_t_train)
		y_pred_t = reg_t.predict(X_t_test)
		mae = np.mean(np.abs(y_pred_t - y_t_test))
		MAEs.append(mae)

		reg = Ridge(alpha=3).fit(X_train, y_train)
		y_pred = reg.predict(X_test)
	else:
		y_pred = np.mean(get_y_train(train)) * np.ones(len(X_test))

	prediction.loc[prediction['label'] == l, 'duration'] = get_result(test[test['label'] == l], y_pred)

prediction['duration_round'] = pd.to_datetime(prediction['duration']).round('1ms')

np.mean(MAEs)
# Out:
# 120.85968138140302

# %%
np.mean(MAEs)
# Out:
# 120.85968138140302

# %%
prediction[['duration_round']].to_csv('result_t_4o.txt', index=False, header=False)

# %%
prediction[prediction['label'] == 'Tbilisijska---VIŽMARJE']
# Out:
#                         label             duration      duration_round
# 3301   Tbilisijska---VIŽMARJE  2012-12-11 04:35:47 2012-12-11 04:35:47
# 3302   Tbilisijska---VIŽMARJE  2012-12-11 06:01:19 2012-12-11 06:01:19
# 3303   Tbilisijska---VIŽMARJE  2012-12-11 07:42:38 2012-12-11 07:42:38
# 3304   Tbilisijska---VIŽMARJE  2012-12-11 09:31:09 2012-12-11 09:31:09
# 3307   Tbilisijska---VIŽMARJE  2012-12-11 15:41:49 2012-12-11 15:41:49
# ...                       ...                  ...                 ...
# 22963  Tbilisijska---VIŽMARJE  2012-12-17 12:21:10 2012-12-17 12:21:10
# 22964  Tbilisijska---VIŽMARJE  2012-12-17 13:54:04 2012-12-17 13:54:04
# 22965  Tbilisijska---VIŽMARJE  2012-12-17 15:26:02 2012-12-17 15:26:02
# 22966  Tbilisijska---VIŽMARJE  2012-12-17 17:10:31 2012-12-17 17:10:31
# 22969  Tbilisijska---VIŽMARJE  2012-12-18 12:45:51 2012-12-18 12:45:51
#
# [827 rows x 3 columns]

# %%
test[test['label'] == 'Tbilisijska---VIŽMARJE']
# Out:
#       Registration  Driver ID Route        Route Direction  Route description  \
# 3301    LJ LPP-165         51     1  MESTNI LOG - VIŽMARJE    VIŽMARJE; sejem
# 3302    LJ LPP-165         51     1  MESTNI LOG - VIŽMARJE    VIŽMARJE; sejem
# 3303    LJ LPP-165         51     1  MESTNI LOG - VIŽMARJE    VIŽMARJE; sejem
# 3304    LJ LPP-165         51     1  MESTNI LOG - VIŽMARJE    VIŽMARJE; sejem
# 3307    LJ LPP-165        229     1  MESTNI LOG - VIŽMARJE    VIŽMARJE; sejem
# ...            ...        ...   ...                    ...                ...
# 22963   LP LPP-392         75     1  MESTNI LOG - VIŽMARJE    VIŽMARJE; sejem
# 22964   LP LPP-392         75     1  MESTNI LOG - VIŽMARJE    VIŽMARJE; sejem
# 22965   LP LPP-392         75     1  MESTNI LOG - VIŽMARJE    VIŽMARJE; sejem
# 22966   LP LPP-392         75     1  MESTNI LOG - VIŽMARJE    VIŽMARJE; sejem
# 22969   LP LPP-392        303     1  MESTNI LOG - VIŽMARJE    VIŽMARJE; sejem
#
#       First station           Departure time Last station Arrival time  \
# 3301    Tbilisijska  2012-12-11 04:01:47.000     VIŽMARJE            ?
# 3302    Tbilisijska  2012-12-11 05:27:19.000     VIŽMARJE            ?
# 3303    Tbilisijska  2012-12-11 07:08:38.000     VIŽMARJE            ?
# 3304    Tbilisijska  2012-12-11 08:57:09.000     VIŽMARJE            ?
# 3307    Tbilisijska  2012-12-11 15:07:49.000     VIŽMARJE            ?
# ...             ...                      ...          ...          ...
# 22963   Tbilisijska  2012-12-17 11:47:10.000     VIŽMARJE            ?
# 22964   Tbilisijska  2012-12-17 13:20:04.000     VIŽMARJE            ?
# 22965   Tbilisijska  2012-12-17 14:52:02.000     VIŽMARJE            ?
# 22966   Tbilisijska  2012-12-17 16:36:31.000     VIŽMARJE            ?
# 22969   Tbilisijska  2012-12-18 12:11:51.000     VIŽMARJE            ?
#
#                         label
# 3301   Tbilisijska---VIŽMARJE
# 3302   Tbilisijska---VIŽMARJE
# 3303   Tbilisijska---VIŽMARJE
# 3304   Tbilisijska---VIŽMARJE
# 3307   Tbilisijska---VIŽMARJE
# ...                       ...
# 22963  Tbilisijska---VIŽMARJE
# 22964  Tbilisijska---VIŽMARJE
# 22965  Tbilisijska---VIŽMARJE
# 22966  Tbilisijska---VIŽMARJE
# 22969  Tbilisijska---VIŽMARJE
#
# [827 rows x 10 columns]
